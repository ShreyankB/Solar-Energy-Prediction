# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics

# %%
train = '/content/drive/MyDrive/ML_Project_Solar/afinal sheets/6_st_train_data.csv'
test = '/content/drive/MyDrive/ML_Project_Solar/afinal sheets/6_st_test_mean.csv'

# %%
df = pd.read_csv(train)

# %%
# correlated_features = set()
# correlation_matrix = df.corr()

# %%
# for i in range(len(correlation_matrix .columns)):
#     for j in range(i):
#         if abs(correlation_matrix.iloc[i, j]) > 0.8:
#             colname = correlation_matrix.columns[i]
#             correlated_features.add(colname)

# %%
# correlated_features

# %%
# df.drop(labels=correlated_features, axis=1, inplace=True)

# %%
df.isna().sum()
# df = df[df['energy'].notna()]
# Out:
# Date                                     0
# stid                                     0
# energy                                   0
# nlat                                     0
# elon                                     0
# elev                                     0
# elevation_control                        0
# elevation_perturbation                   0
# year                                     0
# month                                    0
# day                                      0
# Downward_Short-Wave_Rad_Flux             0
# Total_precipitation                      0
# Downward_Long-Wave_Rad_Flux              0
# Pressure                                 0
# Precipitable_water                       0
# Specific_humidity_height_above_ground    0
# Maximum_temperature                      0
# Minimum_temperature                      0
# Temperature_height_above_ground          0
# Total_cloud_cover                        0
# Upward_Long-Wave_Rad_Flux                0
# Upward_Long-Wave_Rad_Flux_surface        0
# Total_Column-Integrated_Condensate       0
# Upward_Short-Wave_Rad_Flux               0
# Temperature_surface                      0
# dtype: int64

# %%
# stations = ["HINT", "IDAB", "SLAP", "WEST", "BESS", "ACME"]
# final = pd.DataFrame(columns=list(df.columns))

# for station in stations:
#   final = final.append(df[df.stid == station])

# df = final

# %%
# df.drop(columns=["stid", "nearest_lat", "nearest_lon"], inplace=True)

# %%
# df.drop(columns=list(df.columns)[0], inplace=True)
# # df = df.loc[(df.year > 2004) & (df.year < 2008)]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'stid', 'energy', 'nlat', 'elon', 'elev',
#        'elevation_control', 'elevation_perturbation', 'year', 'month', 'day',
#        'Downward_Short-Wave_Rad_Flux', 'Total_precipitation',
#        'Downward_Long-Wave_Rad_Flux', 'Pressure', 'Precipitable_water',
#        'Specific_humidity_height_above_ground', 'Maximum_temperature',
#        'Minimum_temperature', 'Temperature_height_above_ground',
#        'Total_cloud_cover', 'Upward_Long-Wave_Rad_Flux',
#        'Upward_Long-Wave_Rad_Flux_surface',
#        'Total_Column-Integrated_Condensate', 'Upward_Short-Wave_Rad_Flux',
#        'Temperature_surface'],
#       dtype='object')

# %% [markdown]
# ## LAbel encoding

# %%
# le = preprocessing.LabelEncoder()
# le.fit(df["Date"].unique())
# df["Date"] = le.transform(df["Date"])
train_dates = df["Date"]
df.drop(columns="Date", inplace=True)

# %%
le2 = preprocessing.LabelEncoder()
le2.fit(df["stid"].unique())
df["stid"] = le2.transform(df["stid"])

# %%
X = df.loc[:, df.columns != 'energy'].to_numpy(dtype=np.float64)
y = df['energy'].to_numpy(dtype=np.float64)

# %%
df.isna().sum()
# Out:
# stid                                     0
# energy                                   0
# nlat                                     0
# elon                                     0
# elev                                     0
# elevation_control                        0
# elevation_perturbation                   0
# year                                     0
# month                                    0
# day                                      0
# Downward_Short-Wave_Rad_Flux             0
# Total_precipitation                      0
# Downward_Long-Wave_Rad_Flux              0
# Pressure                                 0
# Precipitable_water                       0
# Specific_humidity_height_above_ground    0
# Maximum_temperature                      0
# Minimum_temperature                      0
# Temperature_height_above_ground          0
# Total_cloud_cover                        0
# Upward_Long-Wave_Rad_Flux                0
# Upward_Long-Wave_Rad_Flux_surface        0
# Total_Column-Integrated_Condensate       0
# Upward_Short-Wave_Rad_Flux               0
# Temperature_surface                      0
# dtype: int64

# %% [markdown]
# ## Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state = 45)

# %% [markdown]
# ### GBR

# %% [markdown]
# {"loss": "lad", "n_estimators": 3000, "learning_rate": 0.035, "max_features": 80,  "max_depth": 7, "subsample": 0.5}

# %%
from sklearn.ensemble import GradientBoostingRegressor
# reg = GradientBoostingRegressor()
reg_gbr = GradientBoostingRegressor(loss='lad', n_estimators=3000, max_features=24, learning_rate=0.035, max_depth=7, subsample=0.5, verbose=1)
# reg_gbr.fit(X_train, y_train)
reg_gbr.fit(X, y)
preds = reg_gbr.predict(X_test)
mae4 =  np.sqrt(metrics.mean_squared_error(y_test,preds))
mae4
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:297: FutureWarning: The loss 'lad' was deprecated in v1.0 and will be removed in version 1.2. Use 'absolute_error' which is equivalent.
#   FutureWarning,
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1     6630605.8340      191384.2405           18.13m
#          2     6476802.2550      185923.4948           17.33m
#          3     6251807.1165      178909.8271           18.06m
#          4     6135893.0322      171058.1855           19.40m
#          5     5903373.8856      161237.0026           20.32m
#          6     5785469.6212      157043.3981           20.74m
#          7     5630332.0587      155853.8887           20.95m
#          8     5451905.5406      152528.6327           20.77m
#          9     5331141.1406      137997.4218           21.72m
#         10     5211636.5398      131274.9657           22.50m
#         20     4069966.7258       90301.8466           23.98m
#         30     3358976.9431       57841.7750           20.23m
#         40     2866135.2835       36375.9871           17.56m
#         50     2524477.7028       23390.3732           15.91m
#         60     2324965.9458       13761.8326           14.80m
#         70     2236195.6625        9296.8278           14.02m
#         80     2114790.7578        5637.0830           13.40m
#         90     2040524.1717        4108.2622           12.91m
#        100     1983403.2530        1993.8138           12.73m
#        200     1829188.7133          89.0080           10.55m
#        300     1773673.8430        -100.7391            9.60m
#        400     1715024.5599          44.2031            8.97m
#        500     1699117.0486         -67.5109            8.45m
#        600     1658569.5929         -63.8649            8.01m
#        700     1629259.5221         -24.7550            7.62m
#        800     1612139.1567        -152.9404            7.22m
#        900     1624233.9975         -56.9511            6.85m
#       1000     1580259.1773         -68.7822            6.52m
#       2000     1411786.6284         -68.3865            3.17m
#       3000     1326542.3885         -73.1400            0.00s
# 2530701.1291286633

# %%
reg_gbr.fit(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:297: FutureWarning: The loss 'lad' was deprecated in v1.0 and will be removed in version 1.2. Use 'absolute_error' which is equivalent.
#   FutureWarning,
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1     6654888.5104      190223.5110            9.43m
#          2     6436161.4194      189581.3588            9.45m
#          3     6267089.6668      178168.6824            9.47m
#          4     6091002.6433      170370.4631            9.49m
#          5     5936492.7778      163557.0807            9.47m
#          6     5752882.6463      158033.4442            9.45m
#          7     5618939.6302      151489.2603            9.48m
#          8     5473276.2354      146039.1590            9.53m
#          9     5320810.9198      134931.9414            9.54m
#         10     5218320.9907      135549.7247            9.51m
#         20     4100927.0849       87418.7656            9.47m
#         30     3339512.9432       56085.3465            9.39m
#         40     2875121.9301       37005.7590            9.32m
#         50     2590525.5000       23356.2034            9.28m
#         60     2351477.5011       14810.1071            9.24m
#         70     2205273.8494       10058.5977            9.22m
#         80     2087232.6556        5881.9893            9.18m
#         90     2033096.4093        3384.7032            9.14m
#        100     2040317.4833        1981.4278            9.11m
#        200     1858997.0119         165.6887            8.69m
#        300     1787154.4698         -27.2120            8.33m
#        400     1723113.8334          65.2610            7.99m
#        500     1689016.1635         -13.1921            7.67m
#        600     1662240.5059         114.7836            7.36m
#        700     1618895.8975         -48.8101            7.04m
#        800     1604897.8963         -86.7443            6.73m
#        900     1572508.6814         -55.2359            6.42m
#       1000     1557837.5948         -89.3396            6.11m
#       2000     1422897.7720          -8.7368            3.04m
#       3000     1327999.4361        -142.7281            0.00s
# GradientBoostingRegressor(learning_rate=0.035, loss='lad', max_depth=7,
#                           max_features=24, n_estimators=3000, subsample=0.5,
#                           verbose=1)

# %% [markdown]
# ### using ridge

# %%
rdg_train = Ridge(alpha=0.001)
rdg_train.fit(X_train, y_train)
preds = rdg_train.predict(X_test)
mae1 = np.sqrt(metrics.mean_squared_error(y_test,preds))
mae1
# rdg_train.fit(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:156: LinAlgWarning: Ill-conditioned matrix (rcond=3.27319e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# 3644982.567376767

# %%
rdg_train.fit(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:156: LinAlgWarning: Ill-conditioned matrix (rcond=2.6203e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Ridge(alpha=0.001)

# %% [markdown]
# ### using LR

# %%
from sklearn.linear_model import LinearRegression
lr_train = LinearRegression()
lr_train.fit(X_train, y_train)
preds = lr_train.predict(X_test)
mae2 =  np.sqrt(metrics.mean_squared_error(y_test,preds))
mae2
# Out:
# 3457097.747441344

# %%
lr_train.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Using decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
regressor_train = DecisionTreeRegressor(max_depth=7)
regressor_train.fit(X_train, y_train)
preds = regressor_train.predict(X_test)
mae32 =  np.sqrt(metrics.mean_squared_error(y_test,preds))
mae32
# Out:
# 3473539.143729889

# %% [markdown]
# ### Using lasso

# %%
from sklearn import linear_model
lso_train = linear_model.Lasso(alpha=0.3,normalize=True)
lso_train.fit(X_train, y_train)
preds = lso_train.predict(X_test)
mae4 = np.sqrt(metrics.mean_squared_error(y_test,preds))
mae4
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py:145: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.826e+18, tolerance: 2.024e+15
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# 3475367.2227515243

# %% [markdown]
# ### svr

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y.reshape(-1, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state = 45)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf', verbose=True)
regressor.fit(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [LibSVM]

# %% [markdown]
# ## Polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly_features = PolynomialFeatures(degree=5)

# transforms the existing features to higher degree features.
X_poly = poly_features.fit_transform(X_train)

# fit the transformed features to Linear Regression
poly_model = LinearRegression()
poly_model.fit(X_poly, y_train)

# predicting on training data-set
y_train_predicted = poly_model.predict(X_poly)

# predicting on test data-set
y_test_predict = poly_model.predict(poly_features.fit_transform(X_test))

# %%
mae2 = metrics.mean_absolute_error(y_test,y_test_predict)
mae2
# Out:
# 2336451.074345124

# %% [markdown]
# ## Testing

# %%
test_df = pd.read_csv(test)

# %%
# test_df.drop(labels=correlated_features, axis=1, inplace=True)

# %%
# for col in test_df.columns:
#   print( col + "      " +  str(test_df[col].isna().sum()))

# %%
test_df
# Out:
#                Date  stid  ...  Upward_Short-Wave_Rad_Flux  Temperature_surface
# 0     HINT-20050101  HINT  ...                    7.381818           289.000092
# 1     HINT-20050102  HINT  ...                   11.327272           290.468933
# 2     HINT-20050103  HINT  ...                   18.327272           290.519623
# 3     HINT-20050104  HINT  ...                    8.927273           284.611938
# 4     HINT-20050105  HINT  ...                   44.563637           270.909210
# ...             ...   ...  ...                         ...                  ...
# 6565  ACME-20071227  ACME  ...                   59.636364           274.657043
# 6566  ACME-20071228  ACME  ...                   90.436363           272.393768
# 6567  ACME-20071229  ACME  ...                   82.581818           272.605194
# 6568  ACME-20071230  ACME  ...                   85.890907           273.838928
# 6569  ACME-20071231  ACME  ...                   79.218185           275.282257
#
# [6570 rows x 25 columns]

# %%
test_dates = test_df["Date"]
test_df.drop(columns="Date", inplace=True)

# %%
df_cols = list(df.columns)
df_cols.remove("energy")

# %%
test_df = test_df[df_cols]

# %%
# le3 = preprocessing.LabelEncoder()
# le3.fit(test_df["stid"].unique())
test_df["stid"] = le2.transform(test_df["stid"])

# %%
# le2 = preprocessing.LabelEncoder()
# le2.fit(test_df["Date"].unique())

# %%
# test_df["Date"] = le2.transform(test_df["Date"])

# %%
test_df
# Out:
#       stid      nlat  ...  Upward_Short-Wave_Rad_Flux  Temperature_surface
# 0        2  35.48439  ...                    7.381818           289.000092
# 1        2  35.48439  ...                   11.327272           290.468933
# 2        2  35.48439  ...                   18.327272           290.519623
# 3        2  35.48439  ...                    8.927273           284.611938
# 4        2  35.48439  ...                   44.563637           270.909210
# ...    ...       ...  ...                         ...                  ...
# 6565     0  34.80833  ...                   59.636364           274.657043
# 6566     0  34.80833  ...                   90.436363           272.393768
# 6567     0  34.80833  ...                   82.581818           272.605194
# 6568     0  34.80833  ...                   85.890907           273.838928
# 6569     0  34.80833  ...                   79.218185           275.282257
#
# [6570 rows x 24 columns]

# %%
Xt = test_df.loc[:, test_df.columns != 'energy'].to_numpy(dtype=np.float64)

# %%
preds = reg_gbr.predict(Xt)
preds
# Out:
# array([ 4017660.07955063,  3214407.46851487,  3931741.89504273, ...,
#         9292750.52472105, 11333785.837007  , 12136898.95107888])

# %%
submission_df = pd.DataFrame()

# %%
submission_df["Id"] = test_dates

# %%
# submission_df["Id"] = le2.inverse_transform(test_df["Date"])
submission_df["Expected"] = preds

# %%
# submission_df.loc[(submission_df.Expected < 0), "Expected"] = 0
submission_df.loc[submission_df.Expected < 0]
# Out:
# Empty DataFrame
# Columns: [Id, Expected]
# Index: []

# %%
submission_df.to_csv('final.csv', index=False)

# %%
from google.colab import files
files.download("final.csv")
